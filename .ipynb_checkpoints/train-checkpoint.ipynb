# %%
local = True
train_ratio = 0.7
iter_cnt = 100
checkpoint = 10
# memory issue
input_size = 3000

# %%
if local:
    # %matplotlib inline
import matplotlib
if not local:
    matplotlib.use('Agg')
import pandas as pd
import math
import os
import seaborn as sns
import collections
import matplotlib.pyplot as plt
import numpy as np
import keras.layers as KL
import keras.optimizers as KO
import keras.models as KM
import keras.backend as K

# %%
sample_raw_path = 'data/sample_submission.csv' if local else '/data/sample_submission.csv'
sample_raw = pd.read_csv(sample_raw_path)[:10]

# %%
for k in sample_raw.keys():
    print(k, ': ', sample_raw[k][0])
# Out:
# test_id :  0
# price :  26.738

# %%
train_raw_path = 'data/train.tsv' if local else '/data/train.tsv'
train_raw = pd.read_csv(train_raw_path, sep='\t')

# %%
print('input length: ', len(train_raw))
for k in train_raw.keys():
    print(k)
# Out:
# input length:  1482535
# train_id
# name
# item_condition_id
# category_name
# brand_name
# price
# shipping
# item_description

# %%
test_raw_path = 'data/test.tsv' if local else '/data/test.tsv'
test_raw = pd.read_csv(test_raw_path, sep='\t')

# %%
train_brand_list = list(set(train_raw['brand_name']))
test_brand_list = list(set(test_raw['brand_name']))
print('training brand size: ', len(train_brand_list))
print('testing brand size: ', len(test_brand_list))
print('common brand size: ', len(list(set(train_brand_list)&set(test_brand_list))))
total_brand_list = list(set(train_brand_list)|set(test_brand_list))
brand_dict = {}
for b in total_brand_list:
    brand_dict[b] = len(brand_dict)
print('brand dict size: ', len(brand_dict))
# Out:
# training brand size:  4810
# testing brand size:  3901
# common brand size:  3421
# brand dict size:  5290

# %%
train_raw_size = len(train_raw)
start = np.random.randint(train_raw_size - input_size)
end = start + input_size
train_raw = train_raw[start:end]

# %%
plt.figure(figsize=(20,5))
sns.distplot(train_raw['price'].tolist())
if not local:
    plt.savefig('/output/price_distribution.png')
else:
    plt.show()

# %%
low_price = []
limit = 250
for p in train_raw['price'].tolist():
    if p < limit:
        low_price.append(p)
plt.figure(figsize=(20,5))
sns.distplot(low_price)
if not local:
    plt.savefig('/output/low_price_distribution.png')
else:
    plt.show()

# %%
print('low price range: ', len(low_price))
print('high price range: ', len(train_raw['price'].tolist()) - len(low_price))
# Out:
# low price range:  2980
# high price range:  20

# %%
total_category = []
total_category.extend(train_raw['category_name'].tolist())
total_category.extend(test_raw['category_name'].tolist())
print('total category count: ', len(total_category))
dicts = []
for c in total_category:
    if type(c) == str:
        clist = c.split('/')
        level_of_category = len(clist)
        while level_of_category > len(dicts):
            dicts.append({})
        for i in range(level_of_category):
            current = clist[i]
            if current not in dicts[i]:
                dicts[i][current] = len(dicts[i])
print('level of dicts: ', len(dicts))
# Out:
# total category count:  696359
# level of dicts:  5

# %%
for i in range(len(dicts)):
    print('level ', i, ' dict size: ', len(dicts[i]))
# Out:
# level  0  dict size:  10
# level  1  dict size:  113
# level  2  dict size:  833
# level  3  dict size:  6
# level  4  dict size:  2

# %%
def encode_category(data, dicts, level):
    res = []
    for d in data:
        row = []
        for lv in range(level):
            exrow = [0 for i in range(len(dicts[lv]))]
            if type(d) == str:
                clist = d.split('/')
                if lv < len(clist) and clist[lv] in dicts[lv]:
                    exrow[dicts[lv][clist[lv]]] = 1
            row.extend(exrow)
        res.append(row)
    output = np.array(res)
    return output

# %%
train_category = encode_category(train_raw['category_name'].tolist(), dicts, 2)

# %%
print('training category shape: ', train_category.shape)
# Out:
# training category shape:  (3000, 123)

# %%
total_item_condition = []
total_item_condition.extend(train_raw['item_condition_id'])
total_item_condition.extend(test_raw['item_condition_id'])
print('total item condition id count: ', len(total_item_condition))
print(list(set(total_item_condition)))
condition_list = list(set(total_item_condition))
condition_dict = {}
for i in range(len(condition_list)):
    condition_dict[condition_list[i]] = i
print('condition dict: ', condition_dict)
# Out:
# total item condition id count:  696359
# [1, 2, 3, 4, 5]
# condition dict:  {1: 0, 2: 1, 3: 2, 4: 3, 5: 4}

# %%
def encode_condition(data, condition_dict):
    res = []
    for d in data:
        row = np.zeros((len(condition_dict)))
        row[condition_dict[d]] = 1
        res.append(row)
    output = np.array(res)
    return output

# %%
train_condition = encode_condition(train_raw['item_condition_id'], condition_dict)

# %%
print('training condition shape: ', train_condition.shape)
# Out:
# training condition shape:  (3000, 5)

# %%
def encode_shipping(data):
    res = [[i] for i in data]
    output = np.array(res)
    return output

# %%
train_shipping = encode_shipping(train_raw['shipping'])

# %%
print('training shipping shape: ', train_shipping.shape)
# Out:
# training shipping shape:  (3000, 1)

# %%
def encode_brand(data, brand_dict):
    res = []
    for d in data:
        row = np.zeros((len(brand_dict)))
        if d in brand_dict:
            row[brand_dict[d]] = 1
        res.append(row)
    output = np.array(res)
    return output

# %%
train_brand = encode_brand(train_raw['brand_name'].tolist(), brand_dict)

# %%
print('training brand shape: ', train_brand.shape)
# Out:
# training brand shape:  (3000, 5290)

# %%
train_price = np.array([[i] for i in train_raw['price'].tolist()])

# %%
print('price shape: ', train_price.shape)
# Out:
# price shape:  (3000, 1)

# %%
def get_price_range(price):
    res = 0
    if price < 100:
        res = price // 10
    elif price < 500:
        res = (100 // 10) + 1 + (price - 100) // 50
    else:
        res = (100 // 10) + 1 + ((500 - 100) // 50) + 1 + (price - 500) // 100
    return int(res)

# %%
def encode_price_category(data):
    max_price = 3000
    category_size = get_price_range(max_price) + 1
    print('maximum price is: ', max_price, ', total ', category_size, ' categories')
    res = []
    for d in data:
        row = np.zeros((category_size))
        row[get_price_range(d)] = 1
        res.append(row)
    output = np.array(res)
    return output

# %%
train_price_category = encode_price_category(train_raw['price'].tolist())
# Out:
# maximum price is:  3000 , total  46  categories

# %%
print('train price category shape: ', train_price_category.shape)
# Out:
# train price category shape:  (3000, 46)

# %%
train_condition = np.hstack([train_condition, train_shipping])

# %%
print('condition feature shape: ', train_condition.shape)
# Out:
# condition feature shape:  (3000, 6)

# %%
train_size = round(train_ratio * len(train_raw['price'].tolist()))
x_train_brand = train_brand[:train_size]
print('x_train_brand shape: ', x_train_brand.shape)
x_test_brand = train_brand[train_size:]
print('x_test_brand shape: ', x_test_brand.shape)
y_train_brand = train_price_category[:train_size]
print('y_train_brand shape: ', y_train_brand.shape)
y_test_brand = train_price_category[train_size:]
print('y_test_brand shape: ', y_test_brand.shape)
x_train_category = train_category[:train_size]
print('x_train_category shape: ', x_train_category.shape)
x_test_category = train_category[train_size:]
print('x_test_category shape: ', x_test_category.shape)
y_train_category = train_price_category[:train_size]
print('y_train_category shape: ', y_train_category.shape)
y_test_category = train_price_category[train_size:]
print('y_test_category shape: ', y_test_category.shape)
x_train_condition = train_condition[:train_size]
print('x_train_condition shape: ', x_train_condition.shape)
x_test_condition = train_condition[train_size:]
print('x_test_condition shape: ', x_test_condition.shape)
y_train_condition = train_price[:train_size]
print('y_train_condition shape: ', y_train_condition.shape)
y_test_condition = train_price[train_size:]
print('y_test_condition shape: ', y_test_condition.shape)
# Out:
# x_train_brand shape:  (2100, 5290)
# x_test_brand shape:  (900, 5290)
# y_train_brand shape:  (2100, 46)
# y_test_brand shape:  (900, 46)
# x_train_category shape:  (2100, 123)
# x_test_category shape:  (900, 123)
# y_train_category shape:  (2100, 46)
# y_test_category shape:  (900, 46)
# x_train_condition shape:  (2100, 6)
# x_test_condition shape:  (900, 6)
# y_train_condition shape:  (2100, 1)
# y_test_condition shape:  (900, 1)

# %%
# brand portion
brand_inputs = KL.Input(shape=(x_train_brand.shape[1],))
brand_dnn_1 = KL.Dense(units=128, activation='relu')
x_brand = brand_dnn_1(brand_inputs)
brand_output_layer = KL.Dense(units=y_train_brand.shape[1], activation='softmax')
brand_outputs = brand_output_layer(x_brand)
# category portion
category_inputs = KL.Input(shape=(x_train_category.shape[1],))
category_dnn_1 = KL.Dense(units=128, activation='relu')
x_category = category_dnn_1(category_inputs)
category_output_layer = KL.Dense(units=y_train_category.shape[1], activation='softmax')
category_outputs = category_output_layer(x_category)
# condition portion
condition_inputs = KL.Input(shape=(x_train_condition.shape[1],))
x_condition = KL.Dense(128)(condition_inputs)
condition_outputs = KL.Dense(16)(x_condition)
# combine portion
x_combine = KL.concatenate([KL.multiply([brand_outputs, category_outputs]), condition_outputs], axis=-1)
x_combine = KL.Dense(128, activation='relu')(x_combine)
final_outputs = KL.Dense(y_train_condition.shape[1], activation='relu')(x_combine)

# %%
brand_model = KM.Model(inputs=brand_inputs, outputs=brand_outputs)
brand_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
if os.path.isfile('brand_model.h5'):
    brand_model.load_weights('brand_model.h5')

# %%
brand_train_losses = []
brand_train_acc = []
brand_test_losses = []
brand_test_acc = []
for i in range(iter_cnt):
    H = brand_model.fit(x=x_train_brand, y=y_train_brand, verbose=1)
    brand_train_losses.extend(H.history['loss'])
    brand_train_acc.extend(H.history['acc'])
    if (i+1) % checkpoint == 0:
        score = brand_model.evaluate(x=x_test_brand, y=y_test_brand, verbose=0)
        brand_test_losses.append(score[0])
        brand_test_acc.append(score[1])
# Out:
# Epoch 1/1
# 2100/2100 [==============================] - 1s 658us/step - loss: 1.7857 - acc: 0.3805
# Epoch 1/1
# 2100/2100 [==============================] - 1s 508us/step - loss: 1.7578 - acc: 0.3805
# Epoch 1/1
# 2100/2100 [==============================] - 1s 464us/step - loss: 1.7376 - acc: 0.3843
# Epoch 1/1
# 2100/2100 [==============================] - 1s 481us/step - loss: 1.7182 - acc: 0.3895
# Epoch 1/1
# 2100/2100 [==============================] - 1s 496us/step - loss: 1.7001 - acc: 0.3952
# Epoch 1/1
# 2100/2100 [==============================] - 1s 473us/step - loss: 1.6861 - acc: 0.4014
# Epoch 1/1
# 2100/2100 [==============================] - 1s 473us/step - loss: 1.6690 - acc: 0.4071
# Epoch 1/1
# 2100/2100 [==============================] - 1s 525us/step - loss: 1.6541 - acc: 0.4119
# Epoch 1/1
# 2100/2100 [==============================] - 1s 466us/step - loss: 1.6402 - acc: 0.4210
# Epoch 1/1
# 2100/2100 [==============================] - 1s 486us/step - loss: 1.6259 - acc: 0.4276
# Epoch 1/1
# 2100/2100 [==============================] - 1s 488us/step - loss: 1.6119 - acc: 0.4338
# Epoch 1/1
# 2100/2100 [==============================] - 1s 482us/step - loss: 1.5984 - acc: 0.4433
# Epoch 1/1
# 2100/2100 [==============================] - 1s 493us/step - loss: 1.5854 - acc: 0.4452
# Epoch 1/1
# 2100/2100 [==============================] - 1s 478us/step - loss: 1.5745 - acc: 0.4505
# Epoch 1/1
# 2100/2100 [==============================] - 1s 524us/step - loss: 1.5629 - acc: 0.4514
# Epoch 1/1
# 2100/2100 [==============================] - 1s 486us/step - loss: 1.5506 - acc: 0.4576
# Epoch 1/1
# 2100/2100 [==============================] - 1s 487us/step - loss: 1.5418 - acc: 0.4571
# Epoch 1/1
# 2100/2100 [==============================] - 1s 497us/step - loss: 1.5315 - acc: 0.4605
# Epoch 1/1
# 2100/2100 [==============================] - 1s 528us/step - loss: 1.5233 - acc: 0.4600
# Epoch 1/1
# 2100/2100 [==============================] - 1s 601us/step - loss: 1.5140 - acc: 0.4600
# Epoch 1/1
# 2100/2100 [==============================] - 1s 427us/step - loss: 1.5057 - acc: 0.4619
# Epoch 1/1
# 2100/2100 [==============================] - 1s 414us/step - loss: 1.4998 - acc: 0.4624
# Epoch 1/1
# 2100/2100 [==============================] - 1s 430us/step - loss: 1.4915 - acc: 0.4652
# Epoch 1/1
# 2100/2100 [==============================] - 1s 432us/step - loss: 1.4853 - acc: 0.4624
# Epoch 1/1
# 2100/2100 [==============================] - 1s 426us/step - loss: 1.4798 - acc: 0.4671
# Epoch 1/1
# 2100/2100 [==============================] - 1s 454us/step - loss: 1.4718 - acc: 0.4690
# Epoch 1/1
# 2100/2100 [==============================] - 1s 511us/step - loss: 1.4687 - acc: 0.4700
# Epoch 1/1
# 2100/2100 [==============================] - 1s 457us/step - loss: 1.4623 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 491us/step - loss: 1.4581 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 405us/step - loss: 1.4520 - acc: 0.4690
# Epoch 1/1
# 2100/2100 [==============================] - 1s 415us/step - loss: 1.4489 - acc: 0.4710
# Epoch 1/1
# 2100/2100 [==============================] - 1s 407us/step - loss: 1.4458 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 424us/step - loss: 1.4422 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 439us/step - loss: 1.4378 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 507us/step - loss: 1.4354 - acc: 0.4710
# Epoch 1/1
# 2100/2100 [==============================] - 1s 446us/step - loss: 1.4317 - acc: 0.4710
# Epoch 1/1
# 2100/2100 [==============================] - 1s 515us/step - loss: 1.4270 - acc: 0.4748
# Epoch 1/1
# 2100/2100 [==============================] - 1s 572us/step - loss: 1.4258 - acc: 0.4724
# Epoch 1/1
# 2100/2100 [==============================] - 1s 445us/step - loss: 1.4231 - acc: 0.4686
# Epoch 1/1
# 2100/2100 [==============================] - 1s 488us/step - loss: 1.4201 - acc: 0.4733
# Epoch 1/1
# 2100/2100 [==============================] - 1s 466us/step - loss: 1.4176 - acc: 0.4724
# Epoch 1/1
# 2100/2100 [==============================] - 1s 578us/step - loss: 1.4165 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 571us/step - loss: 1.4134 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 544us/step - loss: 1.4108 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 637us/step - loss: 1.4083 - acc: 0.4738
# Epoch 1/1
# 2100/2100 [==============================] - 1s 605us/step - loss: 1.4078 - acc: 0.4752
# Epoch 1/1
# 2100/2100 [==============================] - 1s 577us/step - loss: 1.4060 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 543us/step - loss: 1.4049 - acc: 0.4705
# Epoch 1/1
# 2100/2100 [==============================] - 1s 610us/step - loss: 1.4025 - acc: 0.4738
# Epoch 1/1
# 2100/2100 [==============================] - 1s 564us/step - loss: 1.3998 - acc: 0.4743
# Epoch 1/1
# 2100/2100 [==============================] - 1s 549us/step - loss: 1.4001 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 562us/step - loss: 1.3992 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 545us/step - loss: 1.3973 - acc: 0.4738
# Epoch 1/1
# 2100/2100 [==============================] - 1s 563us/step - loss: 1.3952 - acc: 0.4724
# Epoch 1/1
# 2100/2100 [==============================] - 1s 579us/step - loss: 1.3937 - acc: 0.4719 0s - loss: 1.3716 - acc: 0.47
# Epoch 1/1
# 2100/2100 [==============================] - 1s 548us/step - loss: 1.3942 - acc: 0.4738
# Epoch 1/1
# 2100/2100 [==============================] - 1s 556us/step - loss: 1.3917 - acc: 0.4738
# Epoch 1/1
# 2100/2100 [==============================] - 1s 551us/step - loss: 1.3920 - acc: 0.4690
# Epoch 1/1
# 2100/2100 [==============================] - 1s 597us/step - loss: 1.3907 - acc: 0.4700
# Epoch 1/1
# 2100/2100 [==============================] - 1s 571us/step - loss: 1.3899 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 583us/step - loss: 1.3891 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 564us/step - loss: 1.3874 - acc: 0.4724
# Epoch 1/1
# 2100/2100 [==============================] - 1s 553us/step - loss: 1.3873 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 575us/step - loss: 1.3862 - acc: 0.4724
# Epoch 1/1
# 2100/2100 [==============================] - 1s 596us/step - loss: 1.3859 - acc: 0.4695
# Epoch 1/1
# 2100/2100 [==============================] - 1s 553us/step - loss: 1.3847 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 550us/step - loss: 1.3842 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 554us/step - loss: 1.3833 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 571us/step - loss: 1.3817 - acc: 0.4690
# Epoch 1/1
# 2100/2100 [==============================] - 1s 576us/step - loss: 1.3826 - acc: 0.4752
# Epoch 1/1
# 2100/2100 [==============================] - 1s 540us/step - loss: 1.3819 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 556us/step - loss: 1.3816 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 548us/step - loss: 1.3808 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 566us/step - loss: 1.3790 - acc: 0.4743
# Epoch 1/1
# 2100/2100 [==============================] - 1s 552us/step - loss: 1.3805 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 563us/step - loss: 1.3792 - acc: 0.4738
# Epoch 1/1
# 2100/2100 [==============================] - 1s 572us/step - loss: 1.3792 - acc: 0.4743
# Epoch 1/1
# 2100/2100 [==============================] - 1s 551us/step - loss: 1.3778 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 545us/step - loss: 1.3775 - acc: 0.4695
# Epoch 1/1
# 2100/2100 [==============================] - 1s 537us/step - loss: 1.3775 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 544us/step - loss: 1.3759 - acc: 0.4743
# Epoch 1/1
# 2100/2100 [==============================] - 1s 581us/step - loss: 1.3765 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 558us/step - loss: 1.3769 - acc: 0.4719
# Epoch 1/1
# 2100/2100 [==============================] - 1s 474us/step - loss: 1.3763 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 479us/step - loss: 1.3761 - acc: 0.4714
# Epoch 1/1
# 2100/2100 [==============================] - 1s 455us/step - loss: 1.3756 - acc: 0.4733
# Epoch 1/1
# 2100/2100 [==============================] - 1s 473us/step - loss: 1.3751 - acc: 0.4700
# Epoch 1/1
# 2100/2100 [==============================] - 1s 482us/step - loss: 1.3749 - acc: 0.4710
# Epoch 1/1
# 2100/2100 [==============================] - 1s 484us/step - loss: 1.3748 - acc: 0.4690
# Epoch 1/1
# 2100/2100 [==============================] - 1s 463us/step - loss: 1.3734 - acc: 0.4710
# Epoch 1/1
# 2100/2100 [==============================] - 1s 473us/step - loss: 1.3735 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 475us/step - loss: 1.3744 - acc: 0.4700
# Epoch 1/1
# 2100/2100 [==============================] - 1s 490us/step - loss: 1.3744 - acc: 0.4705
# Epoch 1/1
# 2100/2100 [==============================] - 1s 482us/step - loss: 1.3721 - acc: 0.4733
# Epoch 1/1
# 2100/2100 [==============================] - 1s 468us/step - loss: 1.3717 - acc: 0.4724
# Epoch 1/1
# 2100/2100 [==============================] - 1s 483us/step - loss: 1.3726 - acc: 0.4695
# Epoch 1/1
# 2100/2100 [==============================] - 1s 477us/step - loss: 1.3722 - acc: 0.4710
# Epoch 1/1
# 2100/2100 [==============================] - 1s 467us/step - loss: 1.3725 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 485us/step - loss: 1.3716 - acc: 0.4729
# Epoch 1/1
# 2100/2100 [==============================] - 1s 489us/step - loss: 1.3713 - acc: 0.4714

# %%
plt.figure()
plt.plot(brand_train_losses)
plt.title('brand_training_loss')
if not local:
    plt.savefig('/output/brand_training_loss.png')
else:
    plt.show()
plt.figure()
plt.plot(brand_train_acc)
plt.title('brand_training_acc')
if not local:
    plt.savefig('/output/brand_training_acc.png')
else:
    plt.show()
plt.figure()
plt.plot(brand_test_losses)
plt.title('brand_testing_loss')
if not local:
    plt.savefig('/output/brand_testing_loss.png')
else:
    plt.show()
plt.figure()
plt.plot(brand_test_acc)
plt.title('brand_testing_acc')
if not local:
    plt.savefig('/output/brand_testing_acc.png')
else:
    plt.show()

# %%
category_model = KM.Model(inputs=category_inputs, outputs=category_outputs)
category_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
if os.path.isfile('category_model.h5'):
    category_model.load_weights('category_model.h5')

# %%
category_train_losses = []
category_train_acc = []
category_test_losses = []
category_test_acc = []
for i in range(iter_cnt):
    H = category_model.fit(x=x_train_category, y=y_train_category, verbose=1)
    category_train_losses.extend(H.history['loss'])
    category_train_acc.extend(H.history['acc'])
    if (i+1) % checkpoint == 0:
        score = category_model.evaluate(x=x_test_category, y=y_test_category, verbose=0)
        category_test_losses.append(score[0])
        category_test_acc.append(score[1])
# Out:
# Epoch 1/1
# 2100/2100 [==============================] - 1s 290us/step - loss: 1.8953 - acc: 0.3400
# Epoch 1/1
# 2100/2100 [==============================] - 0s 78us/step - loss: 1.8311 - acc: 0.3729
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.7942 - acc: 0.3762
# Epoch 1/1
# 2100/2100 [==============================] - 0s 83us/step - loss: 1.7697 - acc: 0.3824
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.7514 - acc: 0.3871
# Epoch 1/1
# 2100/2100 [==============================] - 0s 84us/step - loss: 1.7358 - acc: 0.3838
# Epoch 1/1
# 2100/2100 [==============================] - 0s 87us/step - loss: 1.7244 - acc: 0.3833
# Epoch 1/1
# 2100/2100 [==============================] - 0s 84us/step - loss: 1.7139 - acc: 0.3929
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.7054 - acc: 0.3881
# Epoch 1/1
# 2100/2100 [==============================] - 0s 82us/step - loss: 1.6984 - acc: 0.3914
# Epoch 1/1
# 2100/2100 [==============================] - 0s 91us/step - loss: 1.6911 - acc: 0.3905
# Epoch 1/1
# 2100/2100 [==============================] - 0s 86us/step - loss: 1.6850 - acc: 0.3900
# Epoch 1/1
# 2100/2100 [==============================] - 0s 84us/step - loss: 1.6803 - acc: 0.3957
# Epoch 1/1
# 2100/2100 [==============================] - 0s 84us/step - loss: 1.6763 - acc: 0.3933
# Epoch 1/1
# 2100/2100 [==============================] - 0s 85us/step - loss: 1.6714 - acc: 0.4000
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.6679 - acc: 0.3943
# Epoch 1/1
# 2100/2100 [==============================] - 0s 85us/step - loss: 1.6642 - acc: 0.3957
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.6602 - acc: 0.4010
# Epoch 1/1
# 2100/2100 [==============================] - 0s 87us/step - loss: 1.6576 - acc: 0.3967
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.6541 - acc: 0.3962
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.6510 - acc: 0.3986
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.6491 - acc: 0.3895
# Epoch 1/1
# 2100/2100 [==============================] - 0s 90us/step - loss: 1.6461 - acc: 0.4024
# Epoch 1/1
# 2100/2100 [==============================] - 0s 85us/step - loss: 1.6438 - acc: 0.3995
# Epoch 1/1
# 2100/2100 [==============================] - 0s 87us/step - loss: 1.6419 - acc: 0.4000
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.6397 - acc: 0.3990
# Epoch 1/1
# 2100/2100 [==============================] - 0s 86us/step - loss: 1.6374 - acc: 0.4019
# Epoch 1/1
# 2100/2100 [==============================] - 0s 83us/step - loss: 1.6341 - acc: 0.4038
# Epoch 1/1
# 2100/2100 [==============================] - 0s 86us/step - loss: 1.6334 - acc: 0.4038
# Epoch 1/1
# 2100/2100 [==============================] - 0s 85us/step - loss: 1.6319 - acc: 0.3971
# Epoch 1/1
# 2100/2100 [==============================] - 0s 91us/step - loss: 1.6294 - acc: 0.4014
# Epoch 1/1
# 2100/2100 [==============================] - 0s 98us/step - loss: 1.6280 - acc: 0.4010
# Epoch 1/1
# 2100/2100 [==============================] - 0s 92us/step - loss: 1.6259 - acc: 0.3995
# Epoch 1/1
# 2100/2100 [==============================] - 0s 91us/step - loss: 1.6246 - acc: 0.4029
# Epoch 1/1
# 2100/2100 [==============================] - 0s 90us/step - loss: 1.6235 - acc: 0.3986
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.6222 - acc: 0.4010
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.6199 - acc: 0.4014
# Epoch 1/1
# 2100/2100 [==============================] - 0s 91us/step - loss: 1.6189 - acc: 0.3995
# Epoch 1/1
# 2100/2100 [==============================] - 0s 90us/step - loss: 1.6176 - acc: 0.4029
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.6164 - acc: 0.4071
# Epoch 1/1
# 2100/2100 [==============================] - 0s 90us/step - loss: 1.6153 - acc: 0.4014
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.6138 - acc: 0.4038
# Epoch 1/1
# 2100/2100 [==============================] - 0s 87us/step - loss: 1.6126 - acc: 0.4033
# Epoch 1/1
# 2100/2100 [==============================] - 0s 90us/step - loss: 1.6121 - acc: 0.3995
# Epoch 1/1
# 2100/2100 [==============================] - 0s 94us/step - loss: 1.6111 - acc: 0.4019
# Epoch 1/1
# 2100/2100 [==============================] - 0s 85us/step - loss: 1.6097 - acc: 0.4043
# Epoch 1/1
# 2100/2100 [==============================] - 0s 96us/step - loss: 1.6102 - acc: 0.3990
# Epoch 1/1
# 2100/2100 [==============================] - 0s 93us/step - loss: 1.6076 - acc: 0.3995
# Epoch 1/1
# 2100/2100 [==============================] - 0s 92us/step - loss: 1.6070 - acc: 0.4014
# Epoch 1/1
# 2100/2100 [==============================] - 0s 92us/step - loss: 1.6064 - acc: 0.4029
# Epoch 1/1
# 2100/2100 [==============================] - 0s 86us/step - loss: 1.6053 - acc: 0.3995
# Epoch 1/1
# 2100/2100 [==============================] - 0s 107us/step - loss: 1.6043 - acc: 0.4052
# Epoch 1/1
# 2100/2100 [==============================] - 0s 111us/step - loss: 1.6030 - acc: 0.4048
# Epoch 1/1
# 2100/2100 [==============================] - 0s 104us/step - loss: 1.6030 - acc: 0.4062
# Epoch 1/1
# 2100/2100 [==============================] - 0s 100us/step - loss: 1.6020 - acc: 0.4024
# Epoch 1/1
# 2100/2100 [==============================] - 0s 100us/step - loss: 1.6016 - acc: 0.4010
# Epoch 1/1
# 2100/2100 [==============================] - 0s 108us/step - loss: 1.6010 - acc: 0.4038
# Epoch 1/1
# 2100/2100 [==============================] - 0s 104us/step - loss: 1.5996 - acc: 0.4076
# Epoch 1/1
# 2100/2100 [==============================] - 0s 110us/step - loss: 1.5993 - acc: 0.4010
# Epoch 1/1
# 2100/2100 [==============================] - 0s 107us/step - loss: 1.5993 - acc: 0.4038
# Epoch 1/1
# 2100/2100 [==============================] - 0s 109us/step - loss: 1.5980 - acc: 0.3990
# Epoch 1/1
# 2100/2100 [==============================] - 0s 90us/step - loss: 1.5982 - acc: 0.4014
# Epoch 1/1
# 2100/2100 [==============================] - 0s 85us/step - loss: 1.5968 - acc: 0.3995
# Epoch 1/1
# 2100/2100 [==============================] - 0s 111us/step - loss: 1.5970 - acc: 0.4033
# Epoch 1/1
# 2100/2100 [==============================] - 0s 86us/step - loss: 1.5964 - acc: 0.4048
# Epoch 1/1
# 2100/2100 [==============================] - 0s 97us/step - loss: 1.5945 - acc: 0.4000
# Epoch 1/1
# 2100/2100 [==============================] - 0s 103us/step - loss: 1.5949 - acc: 0.3976
# Epoch 1/1
# 2100/2100 [==============================] - 0s 102us/step - loss: 1.5948 - acc: 0.4076
# Epoch 1/1
# 2100/2100 [==============================] - 0s 97us/step - loss: 1.5946 - acc: 0.3986
# Epoch 1/1
# 2100/2100 [==============================] - 0s 87us/step - loss: 1.5935 - acc: 0.3990
# Epoch 1/1
# 2100/2100 [==============================] - 0s 86us/step - loss: 1.5926 - acc: 0.4000
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.5923 - acc: 0.4000
# Epoch 1/1
# 2100/2100 [==============================] - 0s 95us/step - loss: 1.5914 - acc: 0.4014
# Epoch 1/1
# 2100/2100 [==============================] - 0s 99us/step - loss: 1.5919 - acc: 0.4067
# Epoch 1/1
# 2100/2100 [==============================] - 0s 105us/step - loss: 1.5909 - acc: 0.4000
# Epoch 1/1
# 2100/2100 [==============================] - 0s 94us/step - loss: 1.5918 - acc: 0.3986
# Epoch 1/1
# 2100/2100 [==============================] - 0s 96us/step - loss: 1.5905 - acc: 0.4043
# Epoch 1/1
# 2100/2100 [==============================] - 0s 98us/step - loss: 1.5900 - acc: 0.4005
# Epoch 1/1
# 2100/2100 [==============================] - 0s 94us/step - loss: 1.5899 - acc: 0.4029
# Epoch 1/1
# 2100/2100 [==============================] - 0s 89us/step - loss: 1.5894 - acc: 0.4033
# Epoch 1/1
# 2100/2100 [==============================] - 0s 87us/step - loss: 1.5892 - acc: 0.4010
# Epoch 1/1
# 2100/2100 [==============================] - 0s 82us/step - loss: 1.5888 - acc: 0.4033
# Epoch 1/1
# 2100/2100 [==============================] - 0s 81us/step - loss: 1.5895 - acc: 0.3971
# Epoch 1/1
# 2100/2100 [==============================] - 0s 83us/step - loss: 1.5878 - acc: 0.4048
# Epoch 1/1
# 2100/2100 [==============================] - 0s 82us/step - loss: 1.5891 - acc: 0.3981
# Epoch 1/1
# 2100/2100 [==============================] - 0s 78us/step - loss: 1.5883 - acc: 0.4038
# Epoch 1/1
# 2100/2100 [==============================] - 0s 83us/step - loss: 1.5875 - acc: 0.4024
# Epoch 1/1
# 2100/2100 [==============================] - 0s 88us/step - loss: 1.5874 - acc: 0.4048
# Epoch 1/1
# 2100/2100 [==============================] - 0s 91us/step - loss: 1.5874 - acc: 0.4019
# Epoch 1/1
# 2100/2100 [==============================] - 0s 84us/step - loss: 1.5876 - acc: 0.4043
# Epoch 1/1
# 2100/2100 [==============================] - 0s 77us/step - loss: 1.5867 - acc: 0.3976
# Epoch 1/1
# 2100/2100 [==============================] - 0s 96us/step - loss: 1.5867 - acc: 0.4038
# Epoch 1/1
# 2100/2100 [==============================] - 0s 110us/step - loss: 1.5869 - acc: 0.4029
# Epoch 1/1
# 2100/2100 [==============================] - 0s 109us/step - loss: 1.5856 - acc: 0.4062
# Epoch 1/1
# 2100/2100 [==============================] - 0s 105us/step - loss: 1.5850 - acc: 0.4043
# Epoch 1/1
# 2100/2100 [==============================] - 0s 110us/step - loss: 1.5857 - acc: 0.4043
# Epoch 1/1
# 2100/2100 [==============================] - 0s 93us/step - loss: 1.5855 - acc: 0.4057
# Epoch 1/1
# 2100/2100 [==============================] - 0s 79us/step - loss: 1.5855 - acc: 0.4043
# Epoch 1/1
# 2100/2100 [==============================] - 0s 80us/step - loss: 1.5851 - acc: 0.4010
# Epoch 1/1
# 2100/2100 [==============================] - 0s 85us/step - loss: 1.5848 - acc: 0.4029

# %%
plt.figure()
plt.plot(category_train_losses)
plt.title('category_training_loss')
if not local:
    plt.savefig('/output/category_training_loss.png')
else:
    plt.show()
plt.figure()
plt.plot(category_train_acc)
plt.title('category_training_acc')
if not local:
    plt.savefig('/output/category_training_acc.png')
else:
    plt.show()
plt.figure()
plt.plot(category_test_losses)
plt.title('category_testing_loss')
if not local:
    plt.savefig('/output/category_testing_loss.png')
else:
    plt.show()
plt.figure()
plt.plot(category_test_acc)
plt.title('category_testing_acc')
if not local:
    plt.savefig('/output/category_testing_acc.png')
else:
    plt.show()

# %%
brand_dnn_1.trainable = False
brand_output_layer.trainable = False
category_dnn_1.trainable = False
category_output_layer.trainable = False
combined_model = KM.Model(inputs=[brand_inputs, category_inputs, condition_inputs], outputs=[final_outputs])
combined_model.compile(optimizer='rmsprop', loss='mean_squared_error')
if os.path.isfile('combined_model.h5'):
    combined_model.load_weights('combined_model.h5')

# %%
combined_train_losses = []
combined_test_losses = []
for i in range(iter_cnt):
    H = combined_model.fit(x=[x_train_brand, x_train_category, x_train_condition], y=y_train_condition, verbose=1)
    combined_train_losses.extend(H.history['loss'])
    if (i+1) % checkpoint == 0:
        score = combined_model.evaluate(x=[x_test_brand, x_test_category, x_test_condition], 
                                        y=y_test_condition, verbose=0)
        combined_test_losses.append(score)
# Out:
# Epoch 1/1
# 2100/2100 [==============================] - 1s 468us/step - loss: 1820.7352
# Epoch 1/1
# 2100/2100 [==============================] - 0s 155us/step - loss: 1822.3377
# Epoch 1/1
# 2100/2100 [==============================] - 0s 158us/step - loss: 1821.1468
# Epoch 1/1
# 2100/2100 [==============================] - 0s 165us/step - loss: 1818.9972
# Epoch 1/1
# 2100/2100 [==============================] - 0s 168us/step - loss: 1819.1737
# Epoch 1/1
# 2100/2100 [==============================] - 0s 162us/step - loss: 1818.3953
# Epoch 1/1
# 2100/2100 [==============================] - 0s 156us/step - loss: 1818.7509
# Epoch 1/1
# 2100/2100 [==============================] - 0s 173us/step - loss: 1819.0271
# Epoch 1/1
# 2100/2100 [==============================] - 0s 172us/step - loss: 1819.4163
# Epoch 1/1
# 2100/2100 [==============================] - 0s 181us/step - loss: 1818.6638
# Epoch 1/1
# 2100/2100 [==============================] - ETA: 0s - loss: 1890.79 - 0s 170us/step - loss: 1815.1251
# Epoch 1/1
# 2100/2100 [==============================] - 0s 188us/step - loss: 1817.6089
# Epoch 1/1
# 2100/2100 [==============================] - 0s 174us/step - loss: 1819.5597
# Epoch 1/1
# 2100/2100 [==============================] - 0s 182us/step - loss: 1818.3623
# Epoch 1/1
# 2100/2100 [==============================] - 0s 146us/step - loss: 1814.3490
# Epoch 1/1
# 2100/2100 [==============================] - 0s 160us/step - loss: 1813.2420
# Epoch 1/1
# 2100/2100 [==============================] - 0s 160us/step - loss: 1817.5932
# Epoch 1/1
# 2100/2100 [==============================] - 0s 166us/step - loss: 1814.7549
# Epoch 1/1
# 2100/2100 [==============================] - 0s 184us/step - loss: 1812.0519
# Epoch 1/1
# 2100/2100 [==============================] - 0s 162us/step - loss: 1815.7622
# Epoch 1/1
# 2100/2100 [==============================] - 0s 192us/step - loss: 1813.8174
# Epoch 1/1
# 2100/2100 [==============================] - 0s 176us/step - loss: 1815.3895
# Epoch 1/1
# 2100/2100 [==============================] - 0s 156us/step - loss: 1812.1285
# Epoch 1/1
# 2100/2100 [==============================] - 0s 165us/step - loss: 1813.2630
# Epoch 1/1
# 2100/2100 [==============================] - 0s 173us/step - loss: 1812.4857
# Epoch 1/1
# 2100/2100 [==============================] - 0s 173us/step - loss: 1812.1486
# Epoch 1/1
# 2100/2100 [==============================] - 0s 159us/step - loss: 1806.6587
# Epoch 1/1
# 2100/2100 [==============================] - 0s 182us/step - loss: 1810.3900
# Epoch 1/1
# 2100/2100 [==============================] - 0s 161us/step - loss: 1808.7346
# Epoch 1/1
# 2100/2100 [==============================] - 0s 147us/step - loss: 1810.6966
# Epoch 1/1
# 2100/2100 [==============================] - 0s 161us/step - loss: 1809.1467
# Epoch 1/1
# 2100/2100 [==============================] - 0s 149us/step - loss: 1806.0022
# Epoch 1/1
# 2100/2100 [==============================] - 0s 170us/step - loss: 1810.3602
# Epoch 1/1
# 2100/2100 [==============================] - 0s 152us/step - loss: 1808.4753
# Epoch 1/1
# 2100/2100 [==============================] - 0s 187us/step - loss: 1807.4091
# Epoch 1/1
# 2100/2100 [==============================] - 0s 147us/step - loss: 1806.7775
# Epoch 1/1
# 2100/2100 [==============================] - 0s 157us/step - loss: 1803.5999
# Epoch 1/1
# 2100/2100 [==============================] - 0s 154us/step - loss: 1802.8601
# Epoch 1/1
# 2100/2100 [==============================] - 0s 169us/step - loss: 1807.1700
# Epoch 1/1
# 2100/2100 [==============================] - 0s 163us/step - loss: 1804.0698
# Epoch 1/1
# 2100/2100 [==============================] - 0s 182us/step - loss: 1801.7461
# Epoch 1/1
# 2100/2100 [==============================] - 0s 202us/step - loss: 1805.1192
# Epoch 1/1
# 2100/2100 [==============================] - 0s 160us/step - loss: 1803.5671
# Epoch 1/1
# 2100/2100 [==============================] - 0s 154us/step - loss: 1797.3813
# Epoch 1/1
# 2100/2100 [==============================] - 0s 180us/step - loss: 1802.9001
# Epoch 1/1
# 2100/2100 [==============================] - 0s 175us/step - loss: 1802.2309
# Epoch 1/1
# 2100/2100 [==============================] - 0s 188us/step - loss: 1802.9919
# Epoch 1/1
# 2100/2100 [==============================] - 0s 155us/step - loss: 1800.6560
# Epoch 1/1
# 2100/2100 [==============================] - 0s 172us/step - loss: 1800.9372
# Epoch 1/1
# 2100/2100 [==============================] - 0s 189us/step - loss: 1799.5294
# Epoch 1/1
# 2100/2100 [==============================] - 0s 166us/step - loss: 1798.7028
# Epoch 1/1
# 2100/2100 [==============================] - 0s 174us/step - loss: 1796.7095
# Epoch 1/1
# 2100/2100 [==============================] - 0s 184us/step - loss: 1798.7420
# Epoch 1/1
# 2100/2100 [==============================] - 0s 153us/step - loss: 1799.4970
# Epoch 1/1
# 2100/2100 [==============================] - 0s 160us/step - loss: 1795.5552
# Epoch 1/1
# 2100/2100 [==============================] - 0s 190us/step - loss: 1795.7098
# Epoch 1/1
# 2100/2100 [==============================] - 0s 181us/step - loss: 1795.7194
# Epoch 1/1
# 2100/2100 [==============================] - 0s 181us/step - loss: 1798.2801
# Epoch 1/1
# 2100/2100 [==============================] - 0s 177us/step - loss: 1793.3067
# Epoch 1/1
# 2100/2100 [==============================] - 0s 172us/step - loss: 1792.0137
# Epoch 1/1
# 2100/2100 [==============================] - 0s 160us/step - loss: 1795.7977
# Epoch 1/1
# 2100/2100 [==============================] - 0s 207us/step - loss: 1790.5903
# Epoch 1/1
# 2100/2100 [==============================] - 0s 189us/step - loss: 1792.9478
# Epoch 1/1
# 2100/2100 [==============================] - 0s 139us/step - loss: 1794.3989
# Epoch 1/1
# 2100/2100 [==============================] - 0s 164us/step - loss: 1789.9141
# Epoch 1/1
# 2100/2100 [==============================] - 0s 158us/step - loss: 1788.3115
# Epoch 1/1
# 2100/2100 [==============================] - 0s 172us/step - loss: 1786.8102
# Epoch 1/1
# 2100/2100 [==============================] - 0s 184us/step - loss: 1789.0219
# Epoch 1/1
# 2100/2100 [==============================] - 0s 150us/step - loss: 1789.9092
# Epoch 1/1
# 2100/2100 [==============================] - 0s 160us/step - loss: 1785.8573
# Epoch 1/1
# 2100/2100 [==============================] - 0s 157us/step - loss: 1787.5919
# Epoch 1/1
# 2100/2100 [==============================] - 0s 170us/step - loss: 1788.4827
# Epoch 1/1
# 2100/2100 [==============================] - 0s 168us/step - loss: 1786.5392
# Epoch 1/1
# 2100/2100 [==============================] - 0s 189us/step - loss: 1786.0709
# Epoch 1/1
# 2100/2100 [==============================] - 0s 166us/step - loss: 1784.7791
# Epoch 1/1
# 2100/2100 [==============================] - 0s 172us/step - loss: 1784.8425
# Epoch 1/1
# 2100/2100 [==============================] - 0s 193us/step - loss: 1784.3592
# Epoch 1/1
# 2100/2100 [==============================] - 0s 190us/step - loss: 1782.8330
# Epoch 1/1
# 2100/2100 [==============================] - 0s 196us/step - loss: 1783.1752
# Epoch 1/1
# 2100/2100 [==============================] - 0s 155us/step - loss: 1779.7802
# Epoch 1/1
# 2100/2100 [==============================] - 0s 183us/step - loss: 1778.1106
# Epoch 1/1
# 2100/2100 [==============================] - 0s 185us/step - loss: 1777.9505
# Epoch 1/1
# 2100/2100 [==============================] - 0s 170us/step - loss: 1779.2964
# Epoch 1/1
# 2100/2100 [==============================] - 0s 143us/step - loss: 1778.3033
# Epoch 1/1
# 2100/2100 [==============================] - 0s 196us/step - loss: 1775.9481
# Epoch 1/1
# 2100/2100 [==============================] - 0s 177us/step - loss: 1775.2313
# Epoch 1/1
# 2100/2100 [==============================] - 0s 168us/step - loss: 1774.9091
# Epoch 1/1
# 2100/2100 [==============================] - 0s 225us/step - loss: 1777.5121
# Epoch 1/1
# 2100/2100 [==============================] - 0s 193us/step - loss: 1774.5018
# Epoch 1/1
# 2100/2100 [==============================] - 0s 167us/step - loss: 1769.1600
# Epoch 1/1
# 2100/2100 [==============================] - 0s 200us/step - loss: 1770.5396
# Epoch 1/1
# 2100/2100 [==============================] - 0s 197us/step - loss: 1771.8410
# Epoch 1/1
# 2100/2100 [==============================] - 0s 176us/step - loss: 1768.9301
# Epoch 1/1
# 2100/2100 [==============================] - 0s 160us/step - loss: 1767.3723
# Epoch 1/1
# 2100/2100 [==============================] - 0s 161us/step - loss: 1766.0119
# Epoch 1/1
# 2100/2100 [==============================] - 0s 147us/step - loss: 1769.2589
# Epoch 1/1
# 2100/2100 [==============================] - 0s 183us/step - loss: 1768.4755
# Epoch 1/1
# 2100/2100 [==============================] - 0s 166us/step - loss: 1763.6901
# Epoch 1/1
# 2100/2100 [==============================] - 0s 179us/step - loss: 1767.9057
# Epoch 1/1
# 2100/2100 [==============================] - 0s 143us/step - loss: 1758.8029

# %%
plt.figure()
plt.plot(combined_train_losses)
plt.title('combined_training_loss')
if not local:
    plt.savefig('/output/combined_training_loss.png')
else:
    plt.show()
plt.figure()
plt.plot(combined_test_losses)
plt.title('combined_testing_loss')
if not local:
    plt.savefig('/output/combined_testing_loss.png')
else:
    plt.show()

# %%
predictions = combined_model.predict(x=[x_test_brand, x_test_category, x_test_condition], verbose=1)
# Out:
# 900/900 [==============================] - 0s 319us/step

# %%
for i in range(5):
    print('truth: ', y_test_condition[i][0], ', prediction: ', predictions[i][0])
# Out:
# truth:  18.0 , prediction:  22.6806
# truth:  9.0 , prediction:  14.54
# truth:  30.0 , prediction:  23.8107
# truth:  74.0 , prediction:  33.3802
# truth:  46.0 , prediction:  27.7585

# %%
pred_arr = sum(predictions.tolist()[:100], [])
truth_arr = sum(y_test_condition.tolist()[:100], [])
plt.figure(figsize=(20,5))
plt.plot(pred_arr, label='predictions')
plt.plot(truth_arr, label='truth')
plt.legend()
if not local:
    plt.savefig('/output/truth_vs_predictions.png')
else:
    plt.show()

# %%
brand_model.save_weights('brand_model.h5')
category_model.save_weights('category_model.h5')
combined_model.save_weights('combined_model.h5')
